# %% [markdown]
# <a href="https://colab.research.google.com/github/wang201156/CFD_program/blob/main/Project_3_Two_Dimensional_Viscous_Scaler_Transport.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#### be discarded
import numpy as np
import matplotlib.pyplot as plt
import os

# === 參數設定 ===
use_coarse_grid = False  # 若為 True 則使用 coarse grid 驗證速度
# 設定網格參數

gamma=0
Nu=0.8
u=0.5
v=0.5

if use_coarse_grid:
    nx, ny = 81, 81
else:
    nx, ny = 321, 321


xmax, xmin = 4.0, 0.0
ymax, ymin = 4.0, 0.0
max_steps=40
tol = 1e-5
pi = np.pi

dx = (xmax - xmin) / (nx - 1)
dy = (ymax - ymin) / (ny - 1)
time=Nu /(u/dx + v/dy)

# 初始化矩陣
T =  np.zeros((nx, ny))
TEMP = np.zeros((nx, ny))
x = np.linspace(xmin, xmax, nx)
y = np.linspace(ymin, ymax, ny)
X, Y = np.meshgrid(x, y)

# 設定邊界條件
T[-1, :] = 0   # 底部邊界 T = 0
T[0, :] = 0  # 頂部邊界 T = 0
T[:, 0] = 0   # 左側邊界 T = 0
T[:, -1] = 0  # 右側邊界 T = 0
#=======================================================================================
# 設定初始條件
for i in range(nx):
    for j in range(ny):
      if 0.9 <= x[i] <= 1.1 and 0.9 <= y[j] <= 1.1:
        TEMP[i, j] = np.sin(5*pi*(x[i] - 0.9)) * np.sin(5*pi*(y[j] - 0.9))
T=TEMP.copy()
#=======================================================================================
# 迭代求解

RHS=np.zeros((nx, ny))
Tg = T.copy() # Evaluating residual
error = 1
count = 1
residuals = []

#neighbors coefficient and central coefficient.

aw = gamma*time / (2 * dx**2)
ae = gamma*time / (2 * dx**2)
as_ = gamma*time / (2 * dy**2)
an = gamma*time / (2 * dy**2)
ap = 1+ (aw+ae+as_+an)/2   ##  ap=1+aw+ae+as+an
au = u*time/dx
av = v*time/dy
# === 儲存圖像資料夾 ===
output_dir = "frames"
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
#========================

for step in range(1, max_steps + 1):  #Tij=t_new

  residual = 1.0
  count = 0

  while residual > tol:
    T_new = T.copy()

    for i in range(1, nx - 1):
         for j in range(1, ny - 1):
           # convection term
           cnx=au/2* (T[i,j]-T[i-1,j]  + T_new[i,j]-T_new[i-1,j])
           cny=av/2* (T[i,j]-T[i,j-1]  + T_new[i,j]-T_new[i,j-1])
           # diffusion term(only n)
           diffx=( aw*T[i-1,j]-(aw+ae)*T[i,j]+ae*T[i+1,j] )/2
           diffy=( as_*T[i,j-1]-(as_+an)*T[i,j]+an*T[i,j+1] )/2

           RHS[i, j] = T[i,j] - (cnx+cny) + (diffx+diffy)
           T_new[i, j] = RHS[i,j] + (  aw*T_new[i-1, j] + ae*T_new[i+1, j] + as_*T_new[i, j-1] + an*T_new[i, j+1]  )/2
           T_new[i, j] = T_new[i, j]/ap
    residual = np.linalg.norm(T_new - T) / np.sqrt(nx * ny)
    T = T_new.copy()

  print(f"Step: {step}, Time: {step*time:.5f}, Residual: {residual:.2e}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-0aa7bae5680a> in <cell line: 0>()
#      77            RHS[i, j] = T[i,j] - (cnx+cny) + (diffx+diffy)
#      78            T_new[i, j] = RHS[i,j] + (  aw*T_new[i-1, j] + ae*T_new[i+1, j] + as_*T_new[i, j-1] + an*T_new[i, j+1]  )/2
# ---> 79            T_new[i, j] = T_new[i, j]/ap
#      80     residual = np.linalg.norm(T_new - T) / np.sqrt(nx * ny)
#      81     T = T_new.copy()
#
# KeyboardInterrupt:

# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# === 參數設定 ===
use_coarse_grid = False  # 若為 True 則使用 coarse grid 驗證速度

gamma = 0.001     # 設為 0 或 0.001
Nu = 0.8
u = 0.5
v = 0.5
max_steps = 400
tol = 1e-5
pi = np.pi

# === 空間格點設定 ===
if use_coarse_grid:
    nx, ny = 81, 81
else:
    nx, ny = 321, 321

xmax, xmin = 4.0, 0.0
ymax, ymin = 4.0, 0.0

dx = (xmax - xmin) / (nx - 1)
dy = (ymax - ymin) / (ny - 1)
dt = Nu / (u/dx + v/dy)

x = np.linspace(xmin, xmax, nx)
y = np.linspace(ymin, ymax, ny)
X, Y = np.meshgrid(x, y)

# === 初始條件設定 ===
T = np.zeros((nx, ny))
for i in range(nx):
    for j in range(ny):
        if 0.9 <= x[i] <= 1.1 and 0.9 <= y[j] <= 1.1:
            T[i, j] = np.sin(5 * pi * (x[i] - 0.9)) * np.sin(5 * pi * (y[j] - 0.9))

# === 系數設定 ===
aw = gamma*dt / (2 * dx**2)
ae = gamma*dt / (2 * dx**2)
as_ = gamma*dt / (2 * dy**2)
an = gamma*dt / (2 * dy**2)
ap = 1 + (aw + ae + as_ + an) / 2
au = u * dt / dx
av = v * dt / dy

# === 儲存圖像資料夾 ===
output_dir = "frames"
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# === 時間迴圈 ===
for step in range(1, max_steps + 1):

    residual = 1.0
    T_new = T.copy()

    while residual > tol:
        T_old = T_new.copy()

        for i in range(1, nx - 1):
            for j in range(1, ny - 1):
                # convection term (upwind + Crank–Nicolson)
                cnx = au/2 * ((T[i, j] - T[i-1, j]) + (T_old[i, j] - T_old[i-1, j]))
                cny = av/2 * ((T[i, j] - T[i, j-1]) + (T_old[i, j] - T_old[i, j-1]))

                # diffusion term (central)
                diffx = (aw*T[i-1,j] - (aw+ae)*T[i,j] + ae*T[i+1,j]) / 2
                diffy = (as_*T[i,j-1] - (as_+an)*T[i,j] + an*T[i,j+1]) / 2

                RHS = T[i, j] - (cnx + cny) + (diffx + diffy)
                T_new[i, j] = RHS + aw*T_new[i-1, j] + ae*T_new[i+1, j] + as_*T_new[i, j-1] + an*T_new[i, j+1]
                T_new[i, j] = T_new[i, j] / ap


        residual = np.sum(np.abs(T_new - T_old)) / np.sqrt(nx * ny)  # Evaluating residual( residual normalizes for converge faster)

    T = T_new.copy()

    print(f"Step {step:4d}, Time = {step*dt:.4f}, Residual = {residual:.2e}")

    # 每 40 步畫一次圖
    if step % 40 == 0 or step == max_steps or step==1:
        plt.figure(figsize=(6,5))
        cp = plt.contourf(X, Y, T.T, 20, cmap='jet')
        plt.title(f'Temperature at step {step}')
        plt.xlabel('x')
        plt.ylabel('y')
        plt.colorbar(cp)
        plt.savefig(f"{output_dir}/step_{step:04d}.png")
        plt.close()
# Out:
# Step    1, Time = 0.0100, Residual = 7.81e-06
# Step    2, Time = 0.0200, Residual = 7.70e-06
# Step    3, Time = 0.0300, Residual = 8.82e-06
# Step    4, Time = 0.0400, Residual = 4.58e-06
# Step    5, Time = 0.0500, Residual = 2.62e-06
# Step    6, Time = 0.0600, Residual = 8.68e-06
# Step    7, Time = 0.0700, Residual = 7.54e-06
# Step    8, Time = 0.0800, Residual = 6.92e-06
# Step    9, Time = 0.0900, Residual = 6.62e-06
# Step   10, Time = 0.1000, Residual = 6.42e-06
# Step   11, Time = 0.1100, Residual = 6.32e-06
# Step   12, Time = 0.1200, Residual = 6.29e-06
# Step   13, Time = 0.1300, Residual = 6.29e-06
# Step   14, Time = 0.1400, Residual = 6.34e-06
# Step   15, Time = 0.1500, Residual = 6.43e-06
# Step   16, Time = 0.1600, Residual = 6.53e-06
# Step   17, Time = 0.1700, Residual = 6.65e-06
# Step   18, Time = 0.1800, Residual = 6.81e-06
# Step   19, Time = 0.1900, Residual = 6.99e-06
# Step   20, Time = 0.2000, Residual = 7.17e-06
# Step   21, Time = 0.2100, Residual = 7.38e-06
# Step   22, Time = 0.2200, Residual = 7.61e-06
# Step   23, Time = 0.2300, Residual = 7.85e-06
# Step   24, Time = 0.2400, Residual = 8.12e-06
# Step   25, Time = 0.2500, Residual = 8.40e-06
# Step   26, Time = 0.2600, Residual = 8.70e-06
# Step   27, Time = 0.2700, Residual = 9.02e-06
# Step   28, Time = 0.2800, Residual = 9.37e-06
# Step   29, Time = 0.2900, Residual = 9.73e-06
# Step   30, Time = 0.3000, Residual = 9.75e-07
# Step   31, Time = 0.3100, Residual = 1.01e-06
# Step   32, Time = 0.3200, Residual = 1.04e-06
# Step   33, Time = 0.3300, Residual = 1.08e-06
# Step   34, Time = 0.3400, Residual = 1.12e-06
# Step   35, Time = 0.3500, Residual = 1.16e-06
# Step   36, Time = 0.3600, Residual = 1.20e-06
# Step   37, Time = 0.3700, Residual = 1.25e-06
# Step   38, Time = 0.3800, Residual = 1.29e-06
# Step   39, Time = 0.3900, Residual = 1.34e-06
# Step   40, Time = 0.4000, Residual = 1.40e-06
# Step   41, Time = 0.4100, Residual = 1.46e-06
# Step   42, Time = 0.4200, Residual = 1.52e-06
# Step   43, Time = 0.4300, Residual = 1.58e-06
# Step   44, Time = 0.4400, Residual = 1.65e-06
# Step   45, Time = 0.4500, Residual = 1.72e-06
# Step   46, Time = 0.4600, Residual = 1.80e-06
# Step   47, Time = 0.4700, Residual = 1.87e-06
# Step   48, Time = 0.4800, Residual = 1.96e-06
# Step   49, Time = 0.4900, Residual = 2.05e-06
# Step   50, Time = 0.5000, Residual = 2.15e-06
# Step   51, Time = 0.5100, Residual = 2.24e-06
# Step   52, Time = 0.5200, Residual = 2.35e-06
# Step   53, Time = 0.5300, Residual = 2.46e-06
# Step   54, Time = 0.5400, Residual = 2.58e-06
# Step   55, Time = 0.5500, Residual = 2.70e-06
# Step   56, Time = 0.5600, Residual = 2.84e-06
# Step   57, Time = 0.5700, Residual = 2.98e-06
# Step   58, Time = 0.5800, Residual = 3.12e-06
# Step   59, Time = 0.5900, Residual = 3.28e-06
# Step   60, Time = 0.6000, Residual = 3.45e-06
# Step   61, Time = 0.6100, Residual = 3.62e-06
# Step   62, Time = 0.6200, Residual = 3.80e-06
# Step   63, Time = 0.6300, Residual = 4.00e-06
# Step   64, Time = 0.6400, Residual = 4.21e-06
# Step   65, Time = 0.6500, Residual = 4.43e-06
# Step   66, Time = 0.6600, Residual = 4.66e-06
# Step   67, Time = 0.6700, Residual = 4.90e-06
# Step   68, Time = 0.6800, Residual = 5.16e-06
# Step   69, Time = 0.6900, Residual = 5.44e-06
# Step   70, Time = 0.7000, Residual = 5.72e-06
# Step   71, Time = 0.7100, Residual = 6.04e-06
# Step   72, Time = 0.7200, Residual = 6.37e-06
# Step   73, Time = 0.7300, Residual = 6.71e-06
# Step   74, Time = 0.7400, Residual = 7.07e-06
# Step   75, Time = 0.7500, Residual = 7.46e-06
# Step   76, Time = 0.7600, Residual = 7.88e-06
# Step   77, Time = 0.7700, Residual = 8.31e-06
# Step   78, Time = 0.7800, Residual = 8.77e-06
# Step   79, Time = 0.7900, Residual = 9.26e-06
# Step   80, Time = 0.8000, Residual = 9.78e-06
# Step   81, Time = 0.8100, Residual = 8.24e-07
# Step   82, Time = 0.8200, Residual = 8.68e-07
# Step   83, Time = 0.8300, Residual = 9.14e-07
# Step   84, Time = 0.8400, Residual = 9.64e-07
# Step   85, Time = 0.8500, Residual = 1.02e-06
# Step   86, Time = 0.8600, Residual = 1.07e-06
# Step   87, Time = 0.8700, Residual = 1.13e-06
# Step   88, Time = 0.8800, Residual = 1.19e-06
# Step   89, Time = 0.8900, Residual = 1.26e-06
# Step   90, Time = 0.9000, Residual = 1.33e-06
# Step   91, Time = 0.9100, Residual = 1.40e-06
# Step   92, Time = 0.9200, Residual = 1.48e-06
# Step   93, Time = 0.9300, Residual = 1.56e-06
# Step   94, Time = 0.9400, Residual = 1.65e-06
# Step   95, Time = 0.9500, Residual = 1.74e-06
# Step   96, Time = 0.9600, Residual = 1.84e-06
# Step   97, Time = 0.9700, Residual = 1.95e-06
# Step   98, Time = 0.9800, Residual = 2.06e-06
# Step   99, Time = 0.9900, Residual = 2.17e-06
# Step  100, Time = 1.0000, Residual = 2.30e-06
# Step  101, Time = 1.0100, Residual = 2.43e-06
# Step  102, Time = 1.0200, Residual = 2.57e-06
# Step  103, Time = 1.0300, Residual = 2.72e-06
# Step  104, Time = 1.0400, Residual = 2.88e-06
# Step  105, Time = 1.0500, Residual = 3.04e-06
# Step  106, Time = 1.0600, Residual = 3.22e-06
# Step  107, Time = 1.0700, Residual = 3.41e-06
# Step  108, Time = 1.0800, Residual = 3.61e-06
# Step  109, Time = 1.0900, Residual = 3.82e-06
# Step  110, Time = 1.1000, Residual = 4.05e-06
# Step  111, Time = 1.1100, Residual = 4.29e-06
# Step  112, Time = 1.1200, Residual = 4.54e-06
# Step  113, Time = 1.1300, Residual = 4.81e-06
# Step  114, Time = 1.1400, Residual = 5.09e-06
# Step  115, Time = 1.1500, Residual = 5.40e-06
# Step  116, Time = 1.1600, Residual = 5.72e-06
# Step  117, Time = 1.1700, Residual = 6.06e-06
# Step  118, Time = 1.1800, Residual = 6.43e-06
# Step  119, Time = 1.1900, Residual = 6.81e-06
# Step  120, Time = 1.2000, Residual = 7.22e-06
# Step  121, Time = 1.2100, Residual = 7.66e-06
# Step  122, Time = 1.2200, Residual = 8.13e-06
# Step  123, Time = 1.2300, Residual = 8.62e-06
# Step  124, Time = 1.2400, Residual = 9.14e-06
# Step  125, Time = 1.2500, Residual = 9.69e-06
# Step  126, Time = 1.2600, Residual = 7.64e-07
# Step  127, Time = 1.2700, Residual = 8.09e-07
# Step  128, Time = 1.2800, Residual = 8.57e-07
# Step  129, Time = 1.2900, Residual = 9.08e-07
# Step  130, Time = 1.3000, Residual = 9.62e-07
# Step  131, Time = 1.3100, Residual = 1.02e-06
# Step  132, Time = 1.3200, Residual = 1.08e-06
# Step  133, Time = 1.3300, Residual = 1.15e-06
# Step  134, Time = 1.3400, Residual = 1.21e-06
# Step  135, Time = 1.3500, Residual = 1.29e-06
# Step  136, Time = 1.3600, Residual = 1.37e-06
# Step  137, Time = 1.3700, Residual = 1.45e-06
# Step  138, Time = 1.3800, Residual = 1.54e-06
# Step  139, Time = 1.3900, Residual = 1.63e-06
# Step  140, Time = 1.4000, Residual = 1.73e-06
# Step  141, Time = 1.4100, Residual = 1.83e-06
# Step  142, Time = 1.4200, Residual = 1.94e-06
# Step  143, Time = 1.4300, Residual = 2.06e-06
# Step  144, Time = 1.4400, Residual = 2.19e-06
# Step  145, Time = 1.4500, Residual = 2.32e-06
# Step  146, Time = 1.4600, Residual = 2.47e-06
# Step  147, Time = 1.4700, Residual = 2.62e-06
# Step  148, Time = 1.4800, Residual = 2.78e-06
# Step  149, Time = 1.4900, Residual = 2.95e-06
# Step  150, Time = 1.5000, Residual = 3.13e-06
# Step  151, Time = 1.5100, Residual = 3.33e-06
# Step  152, Time = 1.5200, Residual = 3.53e-06
# Step  153, Time = 1.5300, Residual = 3.75e-06
# Step  154, Time = 1.5400, Residual = 3.98e-06
# Step  155, Time = 1.5500, Residual = 4.23e-06
# Step  156, Time = 1.5600, Residual = 4.50e-06
# Step  157, Time = 1.5700, Residual = 4.78e-06
# Step  158, Time = 1.5800, Residual = 5.07e-06
# Step  159, Time = 1.5900, Residual = 5.39e-06
# Step  160, Time = 1.6000, Residual = 5.73e-06
# Step  161, Time = 1.6100, Residual = 6.08e-06
# Step  162, Time = 1.6200, Residual = 6.47e-06
# Step  163, Time = 1.6300, Residual = 6.87e-06
# Step  164, Time = 1.6400, Residual = 7.30e-06
# Step  165, Time = 1.6500, Residual = 7.76e-06
# Step  166, Time = 1.6600, Residual = 8.25e-06
# Step  167, Time = 1.6700, Residual = 8.77e-06
# Step  168, Time = 1.6800, Residual = 9.33e-06
# Step  169, Time = 1.6900, Residual = 9.91e-06
# Step  170, Time = 1.7000, Residual = 7.52e-07
# Step  171, Time = 1.7100, Residual = 7.99e-07
# Step  172, Time = 1.7200, Residual = 8.49e-07
# Step  173, Time = 1.7300, Residual = 9.02e-07
# Step  174, Time = 1.7400, Residual = 9.58e-07
# Step  175, Time = 1.7500, Residual = 1.02e-06
# Step  176, Time = 1.7600, Residual = 1.08e-06
# Step  177, Time = 1.7700, Residual = 1.15e-06
# Step  178, Time = 1.7800, Residual = 1.22e-06
# Step  179, Time = 1.7900, Residual = 1.30e-06
# Step  180, Time = 1.8000, Residual = 1.38e-06
# Step  181, Time = 1.8100, Residual = 1.47e-06
# Step  182, Time = 1.8200, Residual = 1.56e-06
# Step  183, Time = 1.8300, Residual = 1.66e-06
# Step  184, Time = 1.8400, Residual = 1.76e-06
# Step  185, Time = 1.8500, Residual = 1.87e-06
# Step  186, Time = 1.8600, Residual = 1.99e-06
# Step  187, Time = 1.8700, Residual = 2.12e-06
# Step  188, Time = 1.8800, Residual = 2.25e-06
# Step  189, Time = 1.8900, Residual = 2.39e-06
# Step  190, Time = 1.9000, Residual = 2.54e-06
# Step  191, Time = 1.9100, Residual = 2.70e-06
# Step  192, Time = 1.9200, Residual = 2.88e-06
# Step  193, Time = 1.9300, Residual = 3.06e-06
# Step  194, Time = 1.9400, Residual = 3.25e-06
# Step  195, Time = 1.9500, Residual = 3.46e-06
# Step  196, Time = 1.9600, Residual = 3.68e-06
# Step  197, Time = 1.9700, Residual = 3.92e-06
# Step  198, Time = 1.9800, Residual = 4.17e-06
# Step  199, Time = 1.9900, Residual = 4.43e-06
# Step  200, Time = 2.0000, Residual = 4.71e-06
# Step  201, Time = 2.0100, Residual = 5.02e-06
# Step  202, Time = 2.0200, Residual = 5.34e-06
# Step  203, Time = 2.0300, Residual = 5.68e-06
# Step  204, Time = 2.0400, Residual = 6.04e-06
# Step  205, Time = 2.0500, Residual = 6.43e-06
# Step  206, Time = 2.0600, Residual = 6.85e-06
# Step  207, Time = 2.0700, Residual = 7.29e-06
# Step  208, Time = 2.0800, Residual = 7.76e-06
# Step  209, Time = 2.0900, Residual = 8.25e-06
# Step  210, Time = 2.1000, Residual = 8.79e-06
# Step  211, Time = 2.1100, Residual = 9.35e-06
# Step  212, Time = 2.1200, Residual = 9.96e-06
# Step  213, Time = 2.1300, Residual = 7.38e-07
# Step  214, Time = 2.1400, Residual = 7.85e-07
# Step  215, Time = 2.1500, Residual = 8.35e-07
